# %%
pip install opencv-python
# Out:
# ...
#   Obtaining dependency information for opencv-python from https://files.pythonhosted.org/packages/c7/ec/9dabb6a9abfdebb3c45b0cc52dec901caafef2b2c7e7d6a839ed86d81e91/opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/38.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.6 MB 640.0 kB/s eta 0:01:01
#    ---------------------------------------- 0.2/38.6 MB 2.1 MB/s eta 0:00:19
#     --------------------------------------- 0.7/38.6 MB 4.9 MB/s eta 0:00:08
#     --------------------------------------- 0.9/38.6 MB 4.6 MB/s eta 0:00:09
#    - -------------------------------------- 1.1/38.6 MB 4.5 MB/s eta 0:00:09
#    - -------------------------------------- 1.2/38.6 MB 4.4 MB/s eta 0:00:09
#    - -------------------------------------- 1.2/38.6 MB 4.4 MB/s eta 0:00:09
#    - -------------------------------------- 1.2/38.6 MB 4.4 MB/s eta 0:00:09
# ...

# %%
import smtplib

# %%
import cv2
import numpy as np
import playsound
import smtplib
Fire_Repoted=0
alarm_status=False
Email_Status=False
def play_audio():
    playsound.playsound("C:\\Users\\bussa\\Downloads\\17158-smoke_alarm.wav",True)
def send_mail():
    recipientEmail="varshabussa2@gmail.com"
    recipientEmail=recipientEmail.lower()
    try:
        server=smtplib.SMTP('smtp.gmail.com',587)
        server.ehlo()
        server.starttls()
        sever.login("21951a67h2@iare.ac.in",'varsha@2004')
        server.sendmail('21951a67h2@iare.ac.in',recipientEmail,"Fire acacident happend")
        print("sent to {}".format(recipientEmail))
        server.close()
    except Exception as e:
        print(e)
video=cv2.VideoCapture("firee.mp4")
while True:
    ret,frame=video.read()
    if ret==False:
        break
    blur=cv2.GaussianBlur(frame,(15,15),0)
    hsv=cv2.cvtColor(blur,cv2.COLOR_BGR2HSV)
    lower=[18,50,50]
    higher=[35,255,255]
    lower=np.array(lower,dtype='uint8')
    higher=np.array(higher,dtype='uint8')
    mask=cv2.inRange(hsv,lower,higher)
    output=cv2.bitwise_and(frame,hsv,mask=mask)
    total=cv2.countNonZero(mask)
    if int(total)>1500:
        Fire_Repoted+=1
        if Fire_Repoted>=1:
            if alarm_status==False:
                play_audio()
                alarm_status=True
            if Email_Status==False:
                send_mail()
                Email_Status=True
    cv2.imshow("output",output)
    if cv2.waitKey(1)&0xFF==ord('q'):
        break
cv2.destroyAllWindows()
video.release()
# Out:
# name 'sever' is not defined
